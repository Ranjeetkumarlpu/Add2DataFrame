# %%
import pandas as pd

# %%
df1=pd.read_csv("C:/Users/ranje/OneDrive/Desktop/Dataset/prouni_2005_2019.csv")

# %%
df1
# Out:
#          ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                       2005                    423
# 1                       2005                    423
# 2                       2005                    423
# 3                       2005                    423
# 4                       2005                    423
# ...                      ...                    ...
# 2692535                 2019                  18978
# 2692536                 2019                  18978
# 2692537                 2019                  18978
# 2692538                 2019                  18978
# 2692539                 2019                  18978
#
#                                             NOME_IES_BOLSA         TIPO_BOLSA  \
# 0        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2        UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...

# %%
df2=pd.read_csv("C:\\Users\\ranje\\OneDrive\\Desktop\\Dataset\\Walmart_Store_sales.csv")

# %%
df2
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df3 = pd.concat([df1,df2] ,axis= 0)

# %%
df3.to_csv("Finalmergedata.csv")

# %%
df4=pd.read_csv("mydata1.csv")

# %%
df4
# Out:
#     si name  roll
# 0    1  abc    11
# 1    2  cde    12
# 2    3  abc    13
# 3    4  cde    14
# 4    5  abc    15
# 5    6  cde    16
# 6    7  abc    17
# 7    8  cde    18
# 8    9  abc    19
# 9   10  cde    20
# 10  11  abc    21

# %%
df5=pd.read_csv("mydata2.csv")

# %%
df5
# Out:
#     si classs address
# 0    1     ix     bgp
# 1    2      x   patna
# 2    3     ix  purnia
# 3    4      x     bgp
# 4    5     ix   patna
# 5    6      x  purnia
# 6    7     ix     bgp
# 7    8      x   patna
# 8    9     ix  purnia
# 9   10      x     bgp
# 10  11     ix   patna

# %%
pd.merge(df4 , df5 , on = 'si', how = 'right')
# Out:
#     si name  roll classs address
# 0    1  abc    11     ix     bgp
# 1    2  cde    12      x   patna
# 2    3  abc    13     ix  purnia
# 3    4  cde    14      x     bgp
# 4    5  abc    15     ix   patna
# 5    6  cde    16      x  purnia
# 6    7  abc    17     ix     bgp
# 7    8  cde    18      x   patna
# 8    9  abc    19     ix  purnia
# 9   10  cde    20      x     bgp
# 10  11  abc    21     ix   patna

# %%
df6 = pd.concat([df4,df5] ,axis= 0)

# %%
df6
# Out:
#     si name  roll classs address
# 0    1  abc  11.0    NaN     NaN
# 1    2  cde  12.0    NaN     NaN
# 2    3  abc  13.0    NaN     NaN
# 3    4  cde  14.0    NaN     NaN
# 4    5  abc  15.0    NaN     NaN
# 5    6  cde  16.0    NaN     NaN
# 6    7  abc  17.0    NaN     NaN
# 7    8  cde  18.0    NaN     NaN
# 8    9  abc  19.0    NaN     NaN
# 9   10  cde  20.0    NaN     NaN
# 10  11  abc  21.0    NaN     NaN
# 0    1  NaN   NaN     ix     bgp
# 1    2  NaN   NaN      x   patna
# 2    3  NaN   NaN     ix  purnia
# 3    4  NaN   NaN      x     bgp
# 4    5  NaN   NaN     ix   patna
# 5    6  NaN   NaN      x  purnia
# 6    7  NaN   NaN     ix     bgp
# 7    8  NaN   NaN      x   patna
# 8    9  NaN   NaN     ix  purnia
# 9   10  NaN   NaN      x     bgp
# 10  11  NaN   NaN     ix   patna

# %%
df7 = pd.concat([df4,df5] ,axis= 1)

# %%
df7
# Out:
#     si name  roll  si classs address
# 0    1  abc    11   1     ix     bgp
# 1    2  cde    12   2      x   patna
# 2    3  abc    13   3     ix  purnia
# 3    4  cde    14   4      x     bgp
# 4    5  abc    15   5     ix   patna
# 5    6  cde    16   6      x  purnia
# 6    7  abc    17   7     ix     bgp
# 7    8  cde    18   8      x   patna
# 8    9  abc    19   9     ix  purnia
# 9   10  cde    20  10      x     bgp
# 10  11  abc    21  11     ix   patna

# %%
df7.to_csv("myfinal.csv")

# %%
pwd
# Out:
# 'C:\\Users\\ranje'

# %%
##Datastore myfinal.csv in 'C:\\Users\\ranje'

# %% [markdown]
# #Thank You
